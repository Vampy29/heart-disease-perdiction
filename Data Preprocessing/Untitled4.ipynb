# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filtered_df = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/output_file.csv')

# %%
filtered_df.head()
# Out:
#    subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0    17675016  36961856  16.921725  2173-04-03        9672            9
# 1    16828280  30007565  18.805278  2141-07-09        3778            9
# 2    15408126  30013597   3.695521  2138-05-17        3979            9
# 3    18340438  30029566   2.227118  2115-04-24        9604            9
# 4    12247460  30031157   3.419988  2164-03-25         966            9
#
#    icd_code_y    long_title gender  anchor_age  admission_number
# 0       78552  Septic shock      M          73                 1
# 1       78552  Septic shock      M          84                 1
# 2       78552  Septic shock      M          80                 1
# 3       78552  Septic shock      F          76                 1
# 4       78552  Septic shock      F          69                 1

# %%
filtered_df.shape
# Out:
# (9201, 11)

# %%
creatine_df = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/creatinine_baseline.csv')

# %%
creatine_df.head()
# Out:
#     hadm_id gender        age  scr_min  ckd  mdrd_est  scr_baseline
# 0  25911675      F  78.389982      2.1    1  0.628465      2.100000
# 1  26913865      F  76.486231      1.7    1  0.625337      1.700000
# 2  29654838      F  75.006168      1.4    1  0.622861      1.400000
# 3  24016413      F  46.803035      NaN    0  0.565994      0.565994
# 4  21544441      F  89.421638      0.6    0  0.645490      0.600000

# %%
df_icustays=pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/icustays.csv')

# %%
df_icustays.head()
# Out:
#    subject_id   hadm_id   stay_id       first_careunit        last_careunit  \
# 0    17867402  24528534  31793211  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 1    14435996  28960964  31983544  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 2    17609946  27385897  33183475  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 3    18966770  23483021  34131444  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 4    12776735  20817525  34547665       Neuro Stepdown       Neuro Stepdown
#
#                 intime              outtime       los
# 0  2154-03-03 04:11:00  2154-03-04 18:16:56  1.587454
# 1  2150-06-19 17:57:00  2150-06-22 18:33:54  3.025625
# 2  2138-02-05 18:54:00  2138-02-15 12:42:05  9.741725
# 3  2123-10-25 10:35:00  2123-10-25 18:59:47  0.350544
# 4  2200-07-12 00:33:00  2200-07-13 16:44:40  1.674769

# %%
result = filtered_df.merge(df_icustays[['stay_id', 'hadm_id']], on='stay_id', how='inner')

# %%
result.head()
# Out:
#    subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0    17675016  36961856  16.921725  2173-04-03        9672            9
# 1    16828280  30007565  18.805278  2141-07-09        3778            9
# 2    15408126  30013597   3.695521  2138-05-17        3979            9
# 3    18340438  30029566   2.227118  2115-04-24        9604            9
# 4    12247460  30031157   3.419988  2164-03-25         966            9
#
#    icd_code_y    long_title gender  anchor_age  admission_number   hadm_id
# 0       78552  Septic shock      M          73                 1  29235706
# 1       78552  Septic shock      M          84                 1  22369507
# 2       78552  Septic shock      M          80                 1  25173814
# 3       78552  Septic shock      F          76                 1  25825474
# 4       78552  Septic shock      F          69                 1  20971283

# %%
result_df = result.merge(creatine_df[['hadm_id', 'scr_min', 'scr_baseline', 'ckd', 'mdrd_est']], on='hadm_id', how='inner')

# %%
result_df.head()
# Out:
#    subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0    17675016  36961856  16.921725  2173-04-03        9672            9
# 1    16828280  30007565  18.805278  2141-07-09        3778            9
# 2    15408126  30013597   3.695521  2138-05-17        3979            9
# 3    18340438  30029566   2.227118  2115-04-24        9604            9
# 4    12247460  30031157   3.419988  2164-03-25         966            9
#
#    icd_code_y    long_title gender  anchor_age  admission_number   hadm_id  \
# 0       78552  Septic shock      M          73                 1  29235706
# 1       78552  Septic shock      M          84                 1  22369507
# 2       78552  Septic shock      M          80                 1  25173814
# 3       78552  Septic shock      F          76                 1  25825474
# 4       78552  Septic shock      F          69                 1  20971283
#
#    scr_min  scr_baseline  ckd  mdrd_est
# 0      0.8           0.8    0  0.146122
# ...

# %%
result_df1 = result_df[result_df['ckd'] != 5]

# %%
result_df1.shape
# Out:
# (8743, 16)

# %%
filename = '/content/drive/My Drive/535 Project Data/Data/output_file1.csv'

# %%
result_df1.to_csv(filename, index=False)

# %%
rrt_df = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/rrt.csv')

# %%
rrt_df.head()
# Out:
#     stay_id            charttime  dialysis_present  dialysis_active  \
# 0  30003226  2123-02-26 16:00:00                 1                0
# 1  30003226  2123-02-26 16:00:00                 1                1
# 2  30003226  2123-02-26 16:30:00                 1                1
# 3  30003226  2123-02-26 16:45:00                 1                1
# 4  30003226  2123-02-26 18:00:00                 1                0
#
#   dialysis_type
# 0    Peritoneal
# 1    Peritoneal
# 2    Peritoneal
# 3    Peritoneal
# 4    Peritoneal

# %%
rrt_df['dialysis_type'].unique()
# Out:
# array(['Peritoneal', nan, 'CVVHDF', 'CRRT', 'IHD', 'CVVHD', 'CVVH',
#        'SCUF'], dtype=object)

# %%
df_diagnoses_icd = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/d_icd_diagnoses.csv')

# %%
df_diagnoses_icd.head()
# Out:
#   icd_code  icd_version                             long_title
# 0     0010            9         Cholera due to vibrio cholerae
# 1     0011            9  Cholera due to vibrio cholerae el tor
# 2     0019            9                   Cholera, unspecified
# 3     0020            9                          Typhoid fever
# 4     0021            9                    Paratyphoid fever A

# %%
cardiac_arrest_rows = df_diagnoses_icd[df_diagnoses_icd['icd_code'] == '99.60']

# %%
cardiac_arrest_rows.shape
# Out:
# (0, 3)

# %%
df_procedures_icu = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/procedureevents.csv')

# %%
df_procedures_icu.head()
# Out:
#    subject_id   hadm_id   stay_id            starttime              endtime  \
# 0    15693895  21203492  30500789  2147-06-05 11:25:00  2147-06-05 11:26:00
# 1    15693895  21203492  30500789  2147-06-05 22:00:00  2147-06-05 22:01:00
# 2    12481680  26876606  30863119  2141-01-23 12:00:00  2141-01-23 18:33:00
# 3    12481680  26876606  30863119  2141-01-23 12:00:00  2141-01-23 18:33:00
# 4    15614172  27424463  33484414  2153-07-29 18:13:00  2153-07-31 01:25:00
#
#                 storetime  itemid   value valueuom         location  ...  \
# 0     2147-06-06 11:25:00  225399     1.0      NaN              NaN  ...
# 1     2147-06-06 11:25:00  224385     1.0      NaN              NaN  ...
# 2  2141-01-23 18:33:51.14  224275   393.0      min              NaN  ...
# 3  2141-01-23 18:33:51.14  224275   393.0      min              NaN  ...
# 4     2153-07-31 01:26:00  224277  1872.0      min  RL Post Forearm  ...
#
# ...

# %%
filtered_df22 = df_procedures_icu[df_procedures_icu['itemid'] == 225466]

# %%
filtered_df22.head()
# Out:
#        subject_id   hadm_id   stay_id            starttime  \
# 4839     15371701  26268759  32666850  2176-02-14 11:15:00
# 5576     16504173  25082363  35859388  2110-07-12 10:15:00
# 6774     13025186  25091297  34325450  2189-07-31 14:16:00
# 8455     10518048  23193885  37956744  2187-06-28 17:00:00
# 10740    10433099  28593361  31272962  2148-12-27 11:05:00
#
#                    endtime            storetime  itemid  value valueuom  \
# 4839   2176-02-14 11:16:00  2176-02-14 12:10:00  225466    1.0      NaN
# 5576   2110-07-12 10:16:00  2110-07-12 12:01:00  225466    1.0      NaN
# 6774   2189-07-31 14:17:00  2189-07-31 15:15:00  225466    1.0      NaN
# 8455   2187-06-28 17:01:00  2187-06-28 17:58:00  225466    1.0      NaN
# 10740  2148-12-27 11:06:00  2148-12-27 12:33:00  225466    1.0      NaN
#
#       location  ... patientweight  totalamount  totalamountuom isopenbag  \
# 4839       NaN  ...          80.0          NaN             NaN         0
# ...

# %%
df_procedures_icu['statusdescription'].unique()
# Out:
# array(['FinishedRunning', 'Stopped', 'Paused'], dtype=object)

# %%
df_chart_icu = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/chartevents.csv')
# Out:
# <ipython-input-41-64bb003179f9>:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_chart_icu = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/chartevents.csv')

# %%
df_chart_icu.head()
# Out:
#    subject_id   hadm_id   stay_id            charttime            storetime  \
# 0    10003700  28623837  30600691  2165-04-24 05:10:00  2165-04-24 05:11:00
# 1    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 2    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 3    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 4    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
#
#    itemid value  valuenum valueuom  warning
# 0  228236   0.0       0.0      NaN        0
# 1  225067   0.0       0.0      NaN        0
# 2  225070   1.0       1.0      NaN        0
# 3  225076   1.0       1.0      NaN        0
# 4  225078   1.0       1.0      NaN        0

# %%
df_diagnoses = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/diagnoses_icd.csv')

# %%
df_diagnoses.head()
# Out:
#    subject_id   hadm_id  seq_num icd_code  icd_version
# 0    15734973  20475282        3     2825            9
# 1    15734973  20475282        2    V0251            9
# 2    15734973  20475282        5     V270            9
# 3    15734973  20475282        1    64891            9
# 4    15734973  20475282        4    66481            9

# %%
cardiac_arrest_rows = df_diagnoses[df_diagnoses['icd_code'] == '99.60']

# %%
cardiac_arrest_rows.shape
# Out:
# (0, 5)
