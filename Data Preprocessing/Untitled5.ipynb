# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/My Drive/535 Project Data/Data/output_file1.csv')

# %%
df.head()
# Out:
#    subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0    17675016  36961856  16.921725  2173-04-03        9672            9
# 1    16828280  30007565  18.805278  2141-07-09        3778            9
# 2    15408126  30013597   3.695521  2138-05-17        3979            9
# 3    18340438  30029566   2.227118  2115-04-24        9604            9
# 4    12247460  30031157   3.419988  2164-03-25         966            9
#
#    icd_code_y    long_title gender  anchor_age  admission_number   hadm_id  \
# 0       78552  Septic shock      M          73                 1  29235706
# 1       78552  Septic shock      M          84                 1  22369507
# 2       78552  Septic shock      M          80                 1  25173814
# 3       78552  Septic shock      F          76                 1  25825474
# 4       78552  Septic shock      F          69                 1  20971283
#
#    scr_min  scr_baseline  ckd  mdrd_est
# 0      0.8           0.8    0  0.146122
# ...

# %%
df.shape
# Out:
# (8743, 16)

# %%
df_diagnoses_icd = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/diagnoses_icd.csv')

# %%
df_diagnoses_icd.head()
# Out:
#    subject_id   hadm_id  seq_num icd_code  icd_version
# 0    15734973  20475282        3     2825            9
# 1    15734973  20475282        2    V0251            9
# 2    15734973  20475282        5     V270            9
# 3    15734973  20475282        1    64891            9
# 4    15734973  20475282        4    66481            9

# %%
renal_replacement_rows = df_diagnoses_icd[df_diagnoses_icd['icd_code'] == 'V420']

# %%
renal_replacement_rows.head()
# Out:
#       subject_id   hadm_id  seq_num icd_code  icd_version
# 2178    12248661  23426497        4     V420            9
# 4113    13108883  28065292        4     V420            9
# 4818    17347519  21155616        5     V420            9
# 5326    12152630  20740821        6     V420            9
# 5767    15119601  26362829        3     V420            9

# %%
df1 = df[~df['subject_id'].isin(renal_replacement_rows['subject_id'])]

# %%
df1.shape
# Out:
# (8686, 16)

# %%
cardiac_arrest_rows = df_diagnoses_icd[df_diagnoses_icd['icd_code'] == '4275']

# %%
df1 = df[~df['subject_id'].isin(cardiac_arrest_rows['subject_id'])]

# %%
df1.shape
# Out:
# (8321, 16)

# %%
aki1 = df_diagnoses_icd[df_diagnoses_icd['icd_code'] == '5845']

# %%
aki1.shape
# Out:
# (3362, 5)

# %%
aki1.head()
# Out:
#        subject_id   hadm_id  seq_num icd_code  icd_version
# 2168     12248661  23426497        2     5845            9
# 3342     17602942  23771949        2     5845            9
# 5804     10628593  29116168        5     5845            9
# 6072     19709832  29312025        6     5845            9
# 14062    16816440  25634666        4     5845            9

# %%
aki2 = df_diagnoses_icd[df_diagnoses_icd['icd_code'] == '5847']

# %%
aki2.shape
# Out:
# (5, 5)

# %%
aki2.head()
# Out:
#          subject_id   hadm_id  seq_num icd_code  icd_version
# 110582     15592344  22802310        1     5847            9
# 256230     14524620  29824993        2     5847            9
# 550853     19290587  22694232        2     5847            9
# 1977921    10852773  21977486        3     5847            9
# 2266888    11803145  23162521        5     5847            9

# %%
aki3 = df_diagnoses_icd[df_diagnoses_icd['icd_code'] == '5848']

# %%
aki3.shape
# Out:
# (122, 5)

# %%
aki3.head()
# Out:
#         subject_id   hadm_id  seq_num icd_code  icd_version
# 73673     12870628  24846542        2     5848            9
# 96185     17978572  27365996        2     5848            9
# 104157    12870628  22769400        2     5848            9
# 152617    16400031  28579254        2     5848            9
# 161786    15094515  21602742        2     5848            9

# %%
combined_df = pd.concat([aki1, aki2, aki3], axis=0)

# %%
combined_df.shape
# Out:
# (3489, 5)

# %%
filtered_df1 = df[df['subject_id'].isin(combined_df['subject_id'])]

# %%
filtered_df1.shape
# Out:
# (1024, 16)

# %%
filtered_df1.head()
# Out:
#     subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0     17675016  36961856  16.921725  2173-04-03        9672            9
# 22    19695954  30113662   2.534757  2197-11-08        3893            9
# 25    11880923  30132571  17.632257  2126-01-15        3990            9
# 27    18343701  30139247   2.832755  2158-06-30        8872            9
# 41    14514730  30218515   2.733021  2157-09-05        3734            9
#
#     icd_code_y    long_title gender  anchor_age  admission_number   hadm_id  \
# 0        78552  Septic shock      M          73                 1  29235706
# 22       78552  Septic shock      F          73                 1  26918319
# 25       78552  Septic shock      M          66                 1  21662658
# 27       78552  Septic shock      M          83                 1  26846317
# 41       78552  Septic shock      F          76                 1  27259293
#
#     scr_min  scr_baseline  ckd  mdrd_est
# ...

# %%
filename = '/content/drive/My Drive/535 Project Data/Data/final_data.csv'

# %%
filtered_df.to_csv(filename, index=False)

# %%
df_chartevents = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/chartevents.csv')
# Out:
# <ipython-input-36-d880897475a6>:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_chartevents = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/chartevents.csv')

# %%
df_chartevents.head()
# Out:
#    subject_id   hadm_id   stay_id            charttime            storetime  \
# 0    10003700  28623837  30600691  2165-04-24 05:10:00  2165-04-24 05:11:00
# 1    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 2    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 3    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 4    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
#
#    itemid value  valuenum valueuom  warning
# 0  228236   0.0       0.0      NaN        0
# 1  225067   0.0       0.0      NaN        0
# 2  225070   1.0       1.0      NaN        0
# 3  225076   1.0       1.0      NaN        0
# 4  225078   1.0       1.0      NaN        0

# %%
df_ditems = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/d_items.csv')

# %%
df_ditems.head(50)
# Out:
#     itemid                                   label         abbreviation  \
# 0   220003                      ICU Admission date   ICU Admission date
# 1   220045                              Heart Rate                   HR
# 2   220046                 Heart rate Alarm - High      HR Alarm - High
# 3   220047                  Heart Rate Alarm - Low       HR Alarm - Low
# 4   220048                            Heart Rhythm         Heart Rhythm
# 5   220050        Arterial Blood Pressure systolic                 ABPs
# 6   220051       Arterial Blood Pressure diastolic                 ABPd
# 7   220052            Arterial Blood Pressure mean                 ABPm
# 8   220056     Arterial Blood Pressure Alarm - Low      ABP Alarm - Low
# 9   220058    Arterial Blood Pressure Alarm - High     ABP Alarm - High
# 10  220059      Pulmonary Artery Pressure systolic                 PAPs
# 11  220060     Pulmonary Artery Pressure diastolic                 PAPd
# ...

# %%
hearrate_rows = df_chartevents[df_chartevents['itemid'] == 220045	]

# %%
check = df_ditems[df_ditems['itemid'] == 224684	]

# %%
check.head()
# Out:
#      itemid               label        abbreviation      linksto     category  \
# 605  224684  Tidal Volume (set)  Tidal Volume (set)  chartevents  Respiratory
#
#     unitname param_type  lownormalvalue  highnormalvalue
# 605       mL    Numeric           299.0            750.0

# %%
hearrate_rows.head()
# Out:
#      subject_id   hadm_id   stay_id            charttime            storetime  \
# 15     10003700  28623837  30600691  2165-04-24 05:30:00  2165-04-24 05:37:00
# 37     10003700  28623837  30600691  2165-04-24 06:00:00  2165-04-24 06:09:00
# 68     10003700  28623837  30600691  2165-04-24 06:09:00  2165-04-24 06:09:00
# 72     10003700  28623837  30600691  2165-04-24 07:00:00  2165-04-24 07:51:00
# 122    10003700  28623837  30600691  2165-04-24 08:00:00  2165-04-24 08:19:00
#
#      itemid value  valuenum valueuom  warning
# 15   220045  65.0      65.0      bpm        0
# 37   220045  56.0      56.0      bpm        0
# 68   220045  55.0      55.0      bpm        0
# 72   220045  57.0      57.0      bpm        0
# 122  220045  56.0      56.0      bpm        0

# %%
  filtered_df= filtered_df1[filtered_df1['subject_id'].isin(hearrate_rows['subject_id'])]

# %%
filtered_df1.shape
# Out:
# (1024, 16)

# %%
df_hr = filtered_df1.merge(hearrate_rows[['subject_id', 'value']], on='subject_id', how='inner')

# %%
df_hr.head()
# Out:
#    subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0    17675016  36961856  16.921725  2173-04-03        9672            9
# 1    17675016  36961856  16.921725  2173-04-03        9672            9
# 2    17675016  36961856  16.921725  2173-04-03        9672            9
# 3    17675016  36961856  16.921725  2173-04-03        9672            9
# 4    17675016  36961856  16.921725  2173-04-03        9672            9
#
#    icd_code_y    long_title gender  anchor_age  admission_number   hadm_id  \
# 0       78552  Septic shock      M          73                 1  29235706
# 1       78552  Septic shock      M          73                 1  29235706
# 2       78552  Septic shock      M          73                 1  29235706
# 3       78552  Septic shock      M          73                 1  29235706
# 4       78552  Septic shock      M          73                 1  29235706
#
#    scr_min  scr_baseline  ckd  mdrd_est value
# ...

# %%
df=pd.read_csv('/content/drive/My Drive/535 Project Data/Data/final_data.csv')

# %%
df.shape
# Out:
# (1024, 16)

# %%
df_hr = df.merge(hearrate_rows[['subject_id', 'value']], on='subject_id', how='inner')

# %%
df_hr.shape
# Out:
# (365734, 17)

# %%
df_hr1 = df_hr.drop_duplicates(subset='subject_id', keep='first')

# %%
df_hr1.shape
# Out:
# (1024, 17)

# %%
resprate_rows = df_chartevents[df_chartevents['itemid'] == 220210	]

# %%
resprate_rows.head()
# Out:
#      subject_id   hadm_id   stay_id            charttime            storetime  \
# 16     10003700  28623837  30600691  2165-04-24 05:30:00  2165-04-24 05:37:00
# 41     10003700  28623837  30600691  2165-04-24 06:00:00  2165-04-24 06:09:00
# 69     10003700  28623837  30600691  2165-04-24 06:09:00  2165-04-24 06:09:00
# 76     10003700  28623837  30600691  2165-04-24 07:00:00  2165-04-24 07:51:00
# 126    10003700  28623837  30600691  2165-04-24 08:00:00  2165-04-24 08:19:00
#
#      itemid value  valuenum  valueuom  warning
# 16   220210  14.0      14.0  insp/min        0
# 41   220210  14.0      14.0  insp/min        0
# 69   220210  14.0      14.0  insp/min        0
# 76   220210  14.0      14.0  insp/min        0
# 126  220210  14.0      14.0  insp/min        0

# %%
df_respi = df_hr1.merge(hearrate_rows[['subject_id', 'valuenum']], on='subject_id', how='inner')

# %%
df_respi.shape
# Out:
# (365734, 18)

# %%
df_respi = df_respi.drop_duplicates(subset='subject_id', keep='first')

# %%
df_respi.shape
# Out:
# (1024, 18)

# %%
df_respi.head()
# Out:
#       subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0       17675016  36961856  16.921725  2173-04-03        9672            9
# 1335    19695954  30113662   2.534757  2197-11-08        3893            9
# 1808    11880923  30132571  17.632257  2126-01-15        3990            9
# 2559    18343701  30139247   2.832755  2158-06-30        8872            9
# 3005    14514730  30218515   2.733021  2157-09-05        3734            9
#
#       icd_code_y    long_title gender  anchor_age  admission_number   hadm_id  \
# 0          78552  Septic shock      M          73                 1  29235706
# 1335       78552  Septic shock      F          73                 1  26918319
# 1808       78552  Septic shock      M          66                 1  21662658
# 2559       78552  Septic shock      M          83                 1  26846317
# 3005       78552  Septic shock      F          76                 1  27259293
#
# ...

# %%
df_respi.rename(columns={'value': 'HR', 'valuenum_x': 'Respi_rate'}, inplace=True)

# %%
SPo2_rows = df_chartevents[df_chartevents['itemid'] == 	220277	]

# %%
SPo2_rows.head()
# Out:
#      subject_id   hadm_id   stay_id            charttime            storetime  \
# 17     10003700  28623837  30600691  2165-04-24 05:31:00  2165-04-24 05:37:00
# 42     10003700  28623837  30600691  2165-04-24 06:00:00  2165-04-24 05:42:00
# 70     10003700  28623837  30600691  2165-04-24 06:09:00  2165-04-24 06:09:00
# 77     10003700  28623837  30600691  2165-04-24 07:00:00  2165-04-24 07:37:00
# 127    10003700  28623837  30600691  2165-04-24 08:00:00  2165-04-24 08:19:00
#
#      itemid  value  valuenum valueuom  warning
# 17   220277  100.0     100.0        %        0
# 42   220277  100.0     100.0        %        0
# 70   220277  100.0     100.0        %        0
# 77   220277  100.0     100.0        %        0
# 127  220277  100.0     100.0        %        0

# %%
df_respi = df_respi.merge(SPo2_rows[['subject_id', 'valuenum']], on='subject_id', how='inner')

# %%
df_respi = df_respi.drop_duplicates(subset='subject_id', keep='first')

# %%
df_respi.shape
# Out:
# (1024, 19)

# %%
df_respi.rename(columns={'valuenum': 'SpO2'}, inplace=True)

# %%
df_respi.rename(columns={'valuenum_x': 'Respi_rate'}, inplace=True)

# %%
df_respi.head()
# Out:
#       subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0       17675016  36961856  16.921725  2173-04-03        9672            9
# 1335    19695954  30113662   2.534757  2197-11-08        3893            9
# 1803    11880923  30132571  17.632257  2126-01-15        3990            9
# 2559    18343701  30139247   2.832755  2158-06-30        8872            9
# 2993    14514730  30218515   2.733021  2157-09-05        3734            9
#
#       icd_code_y    long_title gender  anchor_age  admission_number   hadm_id  \
# 0          78552  Septic shock      M          73                 1  29235706
# 1335       78552  Septic shock      F          73                 1  26918319
# 1803       78552  Septic shock      M          66                 1  21662658
# 2559       78552  Septic shock      M          83                 1  26846317
# 2993       78552  Septic shock      F          76                 1  27259293
#
# ...

# %%
df_respi = df_respi.drop('valuenum_y', axis=1)

# %%
pH_rows = df_chartevents[df_chartevents['itemid'] == 	220274	]

# %%
pH_rows.head()
# Out:
#       subject_id   hadm_id   stay_id            charttime  \
# 242     10004235  24181354  34100191  2196-02-24 17:53:00
# 2716    10004235  24181354  34100191  2196-02-27 23:38:00
# 4961    10004720  22081550  35009126  2186-11-16 02:07:00
# 5184    10004720  22081550  35009126  2186-11-16 14:53:00
# 5371    10004720  22081550  35009126  2186-11-17 03:13:00
#
#                 storetime  itemid value  valuenum valueuom  warning
# 242   2196-02-24 17:56:00  220274   7.1      7.10    units        1
# 2716  2196-02-27 23:43:00  220274   7.4      7.40    units        0
# 4961  2186-11-16 02:08:00  220274   7.5      7.50    units        1
# 5184  2186-11-16 14:57:00  220274  7.42      7.42    units        0
# 5371  2186-11-17 03:15:00  220274  7.46      7.46    units        1

# %%
pH_rows.shape
# Out:
# (65798, 10)

# %%
df_respi1 = df_respi.merge(pH_rows[['subject_id', 'valuenum']], on='subject_id', how='inner')

# %%
df_respi1 = df_respi1.drop_duplicates(subset='subject_id', keep='first')

# %%
df_respi1.head()
# Out:
#    subject_id   stay_id        los   chartdate  icd_code_x  icd_version  \
# 0    17675016  36961856  16.921725  2173-04-03        9672            9
# 1    11880923  30132571  17.632257  2126-01-15        3990            9
# 2    18152000  30322635   8.417060  2129-02-06        9915            9
# 3    18152000  30322635   8.417060  2129-02-06        9915            9
# 4    18152000  30322635   8.417060  2129-02-06        9915            9
#
#    icd_code_y    long_title gender  anchor_age  admission_number   hadm_id  \
# 0       78552  Septic shock      M          73                 1  29235706
# 1       78552  Septic shock      M          66                 1  21662658
# 2       78552  Septic shock      M          79                 1  26665096
# 3       78552  Septic shock      M          79                 1  26665096
# 4       78552  Septic shock      M          79                 1  26665096
#
#    scr_min  scr_baseline  ckd  mdrd_est     HR  Respi_rate   SpO2  valuenum
# ...

# %%
filename = '/content/drive/My Drive/535 Project Data/Data/final_data1.csv'

# %%
df_respi.to_csv(filename, index=False)
