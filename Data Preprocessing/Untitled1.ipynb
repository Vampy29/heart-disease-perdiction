# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1= pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/d_labitems.csv')

# %%
disease_itemids=[51067,51070,51963,51073,50912,52546,50841,51977,51032,51080,51787,51052,51081,51937,51082,52024,51099,52000,51106]

# %%
disease_itemids.extend([, , ])

# %%
disease_itemids=df1[df1['label'].str.contains('Creatinine', case=False)]['itemid']
disease_itemids
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-6565223e6b77> in <cell line: 1>()
# ----> 1 disease_itemids=df1[df1['label'].str.contains('Creatinine', case=False)]['itemid']
#       2 disease_itemids
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
# -> 4092         if com.is_bool_indexer(key):
#    4093             return self._getitem_bool_array(key)
#    4094
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     134                     # Don't raise on e.g. ["A", "B", np.nan], see
#     135                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ...

# %%
df1.head()
# Out:
#    itemid                    label        abbreviation         linksto  \
# 0  220003       ICU Admission date  ICU Admission date  datetimeevents
# 1  220045               Heart Rate                  HR     chartevents
# 2  220046  Heart rate Alarm - High     HR Alarm - High     chartevents
# 3  220047   Heart Rate Alarm - Low      HR Alarm - Low     chartevents
# 4  220048             Heart Rhythm        Heart Rhythm     chartevents
#
#               category unitname     param_type  lownormalvalue  \
# 0                  ADT      NaN  Date and time             NaN
# 1  Routine Vital Signs      bpm        Numeric             NaN
# 2               Alarms      bpm        Numeric             NaN
# 3               Alarms      bpm        Numeric             NaN
# 4  Routine Vital Signs      NaN           Text             NaN
#
#    highnormalvalue
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_admissions = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/core/admissions.csv')
df_patients = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/core/patients.csv')
df_diagnoses_icd = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/d_icd_diagnoses.csv')
df_labevents = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/labevents.csv')
df_chartevents = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/chartevents.csv')
# Out:
# <ipython-input-3-83bb2f199d5f>:4: DtypeWarning: Columns (7,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_labevents = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/labevents.csv')
# <ipython-input-3-83bb2f199d5f>:5: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_chartevents = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/chartevents.csv')

# %%
df_icustays=pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/icustays.csv')

# %%
df_icustays.head()
# Out:
#    subject_id   hadm_id   stay_id       first_careunit        last_careunit  \
# 0    17867402  24528534  31793211  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 1    14435996  28960964  31983544  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 2    17609946  27385897  33183475  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 3    18966770  23483021  34131444  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 4    12776735  20817525  34547665       Neuro Stepdown       Neuro Stepdown
#
#                 intime              outtime       los
# 0  2154-03-03 04:11:00  2154-03-04 18:16:56  1.587454
# 1  2150-06-19 17:57:00  2150-06-22 18:33:54  3.025625
# 2  2138-02-05 18:54:00  2138-02-15 12:42:05  9.741725
# 3  2123-10-25 10:35:00  2123-10-25 18:59:47  0.350544
# 4  2200-07-12 00:33:00  2200-07-13 16:44:40  1.674769

# %%
df_labevents = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/labevents.csv')

# %%
df_admissions.head()
# Out:
#    subject_id   hadm_id            admittime            dischtime deathtime  \
# 0    14679932  21038362  2139-09-26 14:16:00  2139-09-28 11:30:00       NaN
# 1    15585972  24941086  2123-10-07 23:56:00  2123-10-12 11:22:00       NaN
# 2    11989120  21965160  2147-01-14 09:00:00  2147-01-17 14:25:00       NaN
# 3    17817079  24709883  2165-12-27 17:33:00  2165-12-31 21:18:00       NaN
# 4    15078341  23272159  2122-08-28 08:48:00  2122-08-30 12:32:00       NaN
#
#   admission_type admission_location discharge_location insurance language  \
# 0       ELECTIVE                NaN               HOME     Other  ENGLISH
# 1       ELECTIVE                NaN               HOME     Other  ENGLISH
# 2       ELECTIVE                NaN               HOME     Other  ENGLISH
# 3       ELECTIVE                NaN               HOME     Other  ENGLISH
# 4       ELECTIVE                NaN               HOME     Other  ENGLISH
#
#   marital_status               ethnicity edregtime edouttime  \
# ...

# %%
df_patients
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  dod
# 0         10000048      F          23         2126       2008 - 2010  NaN
# 1         10002723      F           0         2128       2017 - 2019  NaN
# 2         10003939      M           0         2184       2008 - 2010  NaN
# 3         10004222      M           0         2161       2014 - 2016  NaN
# 4         10005325      F           0         2154       2011 - 2013  NaN
# ...            ...    ...         ...          ...               ...  ...
# 382273    19998203      M          29         2132       2011 - 2013  NaN
# 382274    19998350      M          52         2127       2011 - 2013  NaN
# 382275    19999068      M          63         2161       2011 - 2013  NaN
# 382276    19999270      M          33         2184       2014 - 2016  NaN
# 382277    19999298      M          20         2177       2011 - 2013  NaN
#
# [382278 rows x 6 columns]

# %%
df_diagnoses_icd.head()
# Out:
#   icd_code  icd_version                             long_title
# 0     0010            9         Cholera due to vibrio cholerae
# 1     0011            9  Cholera due to vibrio cholerae el tor
# 2     0019            9                   Cholera, unspecified
# 3     0020            9                          Typhoid fever
# 4     0021            9                    Paratyphoid fever A

# %%
df_labevents.head()
# Out:
#    labevent_id  subject_id  hadm_id  specimen_id  itemid            charttime  \
# 0          670    10000048      NaN      6448755   51484  2126-11-22 19:20:00
# 1          673    10000048      NaN      6448755   51491  2126-11-22 19:20:00
# 2          675    10000048      NaN      6448755   51498  2126-11-22 19:20:00
# 3          683    10000048      NaN     82729055   50861  2126-11-22 20:45:00
# 4          684    10000048      NaN     82729055   50862  2126-11-22 20:45:00
#
#              storetime  value  valuenum valueuom  ref_range_lower  \
# 0  2126-11-22 20:07:00    150   150.000    mg/dL              NaN
# 1  2126-11-22 20:07:00    6.5     6.500    units            5.000
# 2  2126-11-22 20:07:00  1.029     1.029                     1.001
# 3  2126-11-23 00:55:00     39    39.000     IU/L            0.000
# 4  2126-11-23 00:55:00    4.7     4.700     g/dL            3.400
#
#    ref_range_upper flag priority comments
# 0              NaN  NaN     STAT      NaN
# ...

# %%
df_chartevents.head()
# Out:
#    subject_id   hadm_id   stay_id            charttime            storetime  \
# 0    10003700  28623837  30600691  2165-04-24 05:10:00  2165-04-24 05:11:00
# 1    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 2    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 3    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
# 4    10003700  28623837  30600691  2165-04-24 05:12:00  2165-04-24 05:14:00
#
#    itemid value  valuenum valueuom  warning
# 0  228236   0.0       0.0      NaN        0
# 1  225067   0.0       0.0      NaN        0
# 2  225070   1.0       1.0      NaN        0
# 3  225076   1.0       1.0      NaN        0
# 4  225078   1.0       1.0      NaN        0

# %%
df_demo = df_admissions.merge(df_patients, on='subject_id', how='inner')
df_demo = df_demo[['subject_id', 'hadm_id', 'gender', 'anchor_age', 'ethnicity', 'admittime', 'dischtime']]

# %%
df_demo = df_demo.rename(columns={'anchor_age': 'age'})

# %%
df_demo.head()
# Out:
#    subject_id   hadm_id gender  age               ethnicity  \
# 0    14679932  21038362      F    0                 UNKNOWN
# 1    15585972  24941086      F    0                   WHITE
# 2    11989120  21965160      M    0                 UNKNOWN
# 3    17817079  24709883      F    0                   OTHER
# 4    15078341  23272159      M    0  BLACK/AFRICAN AMERICAN
#
#              admittime            dischtime
# 0  2139-09-26 14:16:00  2139-09-28 11:30:00
# 1  2123-10-07 23:56:00  2123-10-12 11:22:00
# 2  2147-01-14 09:00:00  2147-01-17 14:25:00
# 3  2165-12-27 17:33:00  2165-12-31 21:18:00
# 4  2122-08-28 08:48:00  2122-08-30 12:32:00

# %%
df_merged = pd.merge(df_demo, df_icustays, on='subject_id', how='inner')

# %%
df_merged.head()
# Out:
#    subject_id  hadm_id_x gender  age         ethnicity            admittime  \
# 0    15772648   20829310      M   55             WHITE  2145-09-01 19:50:00
# 1    15772648   20829310      M   55             WHITE  2145-09-01 19:50:00
# 2    16296962   24837359      M   29  UNABLE TO OBTAIN  2163-03-17 07:15:00
# 3    16296962   24837359      M   29  UNABLE TO OBTAIN  2163-03-17 07:15:00
# 4    16683560   28552595      M   56           UNKNOWN  2111-11-27 15:08:00
#
#              dischtime  hadm_id_y   stay_id  \
# 0  2145-09-04 14:35:00   26147926  32414483
# 1  2145-09-04 14:35:00   23693642  37927626
# 2  2163-03-21 18:55:00   29416427  31295236
# 3  2163-03-21 18:55:00   29035203  31832800
# 4  2111-11-29 17:04:00   23104974  33967155
#
#                                      first_careunit  \
# 0                               Trauma SICU (TSICU)
# 1  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 2               Surgical Intensive Care Unit (SICU)
# ...

# %%
sepsis_icd_codes = ['99591', '99592', '78552']
df_sepsis = df_diagnoses_icd[df_diagnoses_icd['icd_code'].isin(sepsis_icd_codes)]

# %%
df_sepsis.head()
# Out:
#       icd_code  icd_version     long_title
# 9365     78552            9   Septic shock
# 12082    99591            9         Sepsis
# 12083    99592            9  Severe sepsis

# %%
df_creatinine = df_labevents[df_labevents['itemid'].isin(disease_itemids)]
df_creatinine = df_creatinine[['subject_id', 'hadm_id', 'charttime', 'valuenum']].rename(columns={'valuenum': 'creatinine'})

# %%
df_creatinine.head()
# Out:
#      subject_id  hadm_id            charttime  creatinine  creatinine_change
# 11     10000048      NaN  2126-11-22 20:45:00         0.7                NaN
# 40     10000473      NaN  2138-03-15 22:37:00         1.2                NaN
# 72     10000650      NaN  2142-08-03 21:45:00         1.0                NaN
# 115    10000683      NaN  2175-10-06 19:00:00         0.7                NaN
# 144    10000764      NaN  2132-10-14 20:15:00         1.5                NaN

# %%
df_merged2 = pd.merge(df_demo, df_creatinine, on='subject_id', how='inner')

# %%
df_merged2.head()
# Out:
#    subject_id  hadm_id_x gender  age ethnicity            admittime  \
# 0    10292548   26653546      F   33     ASIAN  2120-01-07 05:51:00
# 1    10292548   26653546      F   33     ASIAN  2120-01-07 05:51:00
# 2    10292548   26653546      F   33     ASIAN  2120-01-07 05:51:00
# 3    10292548   26653546      F   33     ASIAN  2120-01-07 05:51:00
# 4    10292548   26653546      F   33     ASIAN  2120-01-07 05:51:00
#
#              dischtime   hadm_id_y            charttime  creatinine  \
# 0  2120-01-12 13:45:00         NaN  2118-01-01 11:45:00         0.8
# 1  2120-01-12 13:45:00         NaN  2119-05-28 10:30:00         0.6
# 2  2120-01-12 13:45:00         NaN  2119-07-04 14:40:00         0.6
# 3  2120-01-12 13:45:00         NaN  2119-07-26 03:30:00         0.6
# 4  2120-01-12 13:45:00  24067979.0  2119-07-26 09:13:00         0.6
#
#    creatinine_change
# 0                NaN
# 1               -0.2
# 2                0.0
# 3                0.0
# 4                0.0

# %%
df_merged2.shape
# Out:
# (8358038, 11)

# %%
df_merged2 = df_merged2[df_merged2['age'] > 65]

# %%
df_merged2.drop(columns=['charttime'])
# Out:
#           subject_id  hadm_id_x gender  age ethnicity            admittime  \
# 9           19120008   24459786      M   70     ASIAN  2185-09-18 11:15:00
# 10          19120008   24459786      M   70     ASIAN  2185-09-18 11:15:00
# 11          19120008   24459786      M   70     ASIAN  2185-09-18 11:15:00
# 12          19120008   24459786      M   70     ASIAN  2185-09-18 11:15:00
# 13          19120008   24459786      M   70     ASIAN  2185-09-18 11:15:00
# ...              ...        ...    ...  ...       ...                  ...
# 25351376    11211939   24981356      F   85     WHITE  2147-08-02 15:49:00
# 25351377    11211939   24981356      F   85     WHITE  2147-08-02 15:49:00
# 25351378    11211939   24981356      F   85     WHITE  2147-08-02 15:49:00
# 25351379    11211939   24981356      F   85     WHITE  2147-08-02 15:49:00
# 25351380    11211939   24981356      F   85     WHITE  2147-08-02 15:49:00
#
# ...

# %%
df_merged2 = df_merged2[df_merged2['creatinine'] >= 0.3]

# %%
df_merged2.shape
# Out:
# (8294817, 11)

# %%
df_creatinine.head()
# Out:
#      subject_id  hadm_id            charttime  creatinine  creatinine_change
# 11     10000048      NaN  2126-11-22 20:45:00         0.7                NaN
# 40     10000473      NaN  2138-03-15 22:37:00         1.2                NaN
# 72     10000650      NaN  2142-08-03 21:45:00         1.0                NaN
# 115    10000683      NaN  2175-10-06 19:00:00         0.7                NaN
# 144    10000764      NaN  2132-10-14 20:15:00         1.5                NaN

# %%
df_creatinine['creatinine_change'] = df_creatinine.groupby('subject_id')['creatinine'].diff()
aki_criteria = (df_creatinine['creatinine'] >= 0.3) | (df_creatinine['creatinine_change'] >= 0.5)
df_aki = df_creatinine[aki_criteria]
df_aki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3672510 entries, 11 to 121883333
# Data columns (total 5 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   subject_id         int64
#  1   hadm_id            float64
#  2   charttime          object
#  3   creatinine         float64
#  4   creatinine_change  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 168.1+ MB

# %%
df_aki.head()
# Out:
#      subject_id  hadm_id           charttime  creatinine  creatinine_change  \
# 11     10000048      NaN 2126-11-22 20:45:00         0.7                NaN
# 40     10000473      NaN 2138-03-15 22:37:00         1.2                NaN
# 72     10000650      NaN 2142-08-03 21:45:00         1.0                NaN
# 115    10000683      NaN 2175-10-06 19:00:00         0.7                NaN
# 144    10000764      NaN 2132-10-14 20:15:00         1.5                NaN
#
#      charttime_diff
# 11              NaN
# 40              NaN
# 72              NaN
# 115             NaN
# 144             NaN

# %%
df_aki['charttime'] = pd.to_datetime(df_aki['charttime'], errors='coerce')
# Out:
# <ipython-input-20-71aec92d6180>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aki['charttime'] = pd.to_datetime(df_aki['charttime'], errors='coerce')

# %%
df_aki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3672510 entries, 11 to 121883333
# Data columns (total 5 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   subject_id         int64
#  1   hadm_id            float64
#  2   charttime          datetime64[ns]
#  3   creatinine         float64
#  4   creatinine_change  float64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 168.1 MB

# %%
df_aki['charttime_diff'] = df_aki.groupby('subject_id')['charttime'].diff().dt.total_seconds() / 3600
persistent_aki = df_aki[df_aki['charttime_diff'] > 48]
transient_aki = df_aki[df_aki['charttime_diff'] <= 48]
# Out:
# <ipython-input-22-6ecf4dc5f6cd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aki['charttime_diff'] = df_aki.groupby('subject_id')['charttime'].diff().dt.total_seconds() / 3600

# %%
ventilation_labels = ['Mechanical Ventilation', 'Renal Replacement Therapy']
df_interventions = df_chartevents[df_chartevents['label'].isin(ventilation_labels)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-0a060ce4fc01> in <cell line: 2>()
# ...
