# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# sepsis code check

# %%
df_diagnoses_icd = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/d_icd_diagnoses.csv')

# %%
df_diagnoses_icd.head()
# Out:
#       icd_code  icd_version     long_title
# 9365     78552            9   Septic shock
# 12082    99591            9         Sepsis
# 12083    99592            9  Severe sepsis

# %%
df_diagnoses_icd = df_diagnoses_icd[df_diagnoses_icd['icd_code'].isin(['99591', '99592', '78552'])]

# %% [markdown]
# looking at the data

# %%
df_procedures = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/hosp/procedures_icd.csv')

# %%
df_procedures.head()
# Out:
#    subject_id   hadm_id  seq_num   chartdate icd_code  icd_version
# 0    10287061  27485182        1  2124-08-22     7569            9
# 1    13135573  22286210        3  2187-05-30     7309            9
# 2    13135573  22286210        1  2187-05-30     7569            9
# 3    13135573  22286210        2  2187-05-30      734            9
# 4    12646116  24154012        2  2115-01-13      734            9

# %%
df_icustays=pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/icustays.csv')

# %%
df_icustays.head()
# Out:
#     subject_id   hadm_id   stay_id       first_careunit        last_careunit  \
# 1     14435996  28960964  31983544  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 2     17609946  27385897  33183475  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 7     15914763  28906020  36909804  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 14    18599212  28538226  33267162  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 15    14609218  20606189  34947848       Neuro Stepdown       Neuro Stepdown
#
#                  intime              outtime       los
# 1   2150-06-19 17:57:00  2150-06-22 18:33:54  3.025625
# 2   2138-02-05 18:54:00  2138-02-15 12:42:05  9.741725
# 7   2176-12-14 12:00:00  2176-12-17 11:47:01  2.990984
# 14  2129-06-01 16:27:39  2129-06-06 17:01:33  5.023542
# 15  2174-06-28 21:13:00  2174-07-05 17:01:32  6.825370

# %%
df_icustays = df_icustays[df_icustays['los'] > 2]

# %%
df_patients = pd.read_csv('/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/core/patients.csv')

# %%
df_patients
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  dod
# 0         10000048      F          23         2126       2008 - 2010  NaN
# 1         10002723      F           0         2128       2017 - 2019  NaN
# 2         10003939      M           0         2184       2008 - 2010  NaN
# 3         10004222      M           0         2161       2014 - 2016  NaN
# 4         10005325      F           0         2154       2011 - 2013  NaN
# ...            ...    ...         ...          ...               ...  ...
# 382273    19998203      M          29         2132       2011 - 2013  NaN
# 382274    19998350      M          52         2127       2011 - 2013  NaN
# 382275    19999068      M          63         2161       2011 - 2013  NaN
# 382276    19999270      M          33         2184       2014 - 2016  NaN
# 382277    19999298      M          20         2177       2011 - 2013  NaN
#
# [382278 rows x 6 columns]

# %% [markdown]
# joining tables

# %%
merged_df = pd.merge(df_procedures, df_diagnoses_icd, on='icd_version', how='inner')

# %%
merged_df.head()
# Out:
#    subject_id   hadm_id  seq_num   chartdate icd_code_x  icd_version  \
# 0    10287061  27485182        1  2124-08-22       7569            9
# 1    10287061  27485182        1  2124-08-22       7569            9
# 2    10287061  27485182        1  2124-08-22       7569            9
# 3    13135573  22286210        3  2187-05-30       7309            9
# 4    13135573  22286210        3  2187-05-30       7309            9
#
#   icd_code_y     long_title
# 0      78552   Septic shock
# 1      99591         Sepsis
# 2      99592  Severe sepsis
# 3      78552   Septic shock
# 4      99591         Sepsis

# %%
result_df = pd.merge(df_icustays, merged_df, on='subject_id', how='inner')

# %%
result_df.head()
# Out:
#    subject_id  hadm_id_x   stay_id       first_careunit        last_careunit  \
# 0    14435996   28960964  31983544  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 1    14435996   28960964  31983544  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 2    14435996   28960964  31983544  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 3    14435996   28960964  31983544  Trauma SICU (TSICU)  Trauma SICU (TSICU)
# 4    14435996   28960964  31983544  Trauma SICU (TSICU)  Trauma SICU (TSICU)
#
#                 intime              outtime       los  hadm_id_y  seq_num  \
# 0  2150-06-19 17:57:00  2150-06-22 18:33:54  3.025625   28722512        1
# 1  2150-06-19 17:57:00  2150-06-22 18:33:54  3.025625   28722512        1
# 2  2150-06-19 17:57:00  2150-06-22 18:33:54  3.025625   28722512        1
# 3  2150-06-19 17:57:00  2150-06-22 18:33:54  3.025625   28722512        2
# 4  2150-06-19 17:57:00  2150-06-22 18:33:54  3.025625   28722512        2
#
# ...

# %%
df_dropped2 = result_df.drop(columns=['first_careunit', 'last_careunit', 'hadm_id_x','hadm_id_y','intime', 'outtime'])

# %%
df_dropped = result_df.drop(columns=['intime', 'outtime'])

# %%
df_dropped2
# Out:
#         subject_id   stay_id       los  seq_num   chartdate icd_code_x  \
# 0         14435996  31983544  3.025625        1  2143-04-29       8102
# 1         14435996  31983544  3.025625        1  2143-04-29       8102
# 2         14435996  31983544  3.025625        1  2143-04-29       8102
# 3         14435996  31983544  3.025625        2  2143-04-29       8051
# 4         14435996  31983544  3.025625        2  2143-04-29       8051
# ...            ...       ...       ...      ...         ...        ...
# 917440    17577670  39993265  2.579363        5  2154-01-09       4639
# 917441    17577670  39993265  2.579363        5  2154-01-09       4639
# 917442    17577670  39993265  2.579363        6  2154-01-10       3893
# 917443    17577670  39993265  2.579363        6  2154-01-10       3893
# 917444    17577670  39993265  2.579363        6  2154-01-10       3893
#
#         icd_version icd_code_y     long_title
# 0                 9      78552   Septic shock
# ...

# %%
filtered_df1 = df_dropped2[df_dropped2['icd_version'] == 9]

# %%
filtered_df1
# Out:
#         subject_id   stay_id       los  seq_num   chartdate icd_code_x  \
# 0         14435996  31983544  3.025625        1  2143-04-29       8102
# 1         14435996  31983544  3.025625        1  2143-04-29       8102
# 2         14435996  31983544  3.025625        1  2143-04-29       8102
# 3         14435996  31983544  3.025625        2  2143-04-29       8051
# 4         14435996  31983544  3.025625        2  2143-04-29       8051
# ...            ...       ...       ...      ...         ...        ...
# 917440    17577670  39993265  2.579363        5  2154-01-09       4639
# 917441    17577670  39993265  2.579363        5  2154-01-09       4639
# 917442    17577670  39993265  2.579363        6  2154-01-10       3893
# 917443    17577670  39993265  2.579363        6  2154-01-10       3893
# 917444    17577670  39993265  2.579363        6  2154-01-10       3893
#
#         icd_version icd_code_y     long_title
# 0                 9      78552   Septic shock
# ...

# %%
merged_df2 = pd.merge(filtered_df1, df_patients, on='subject_id', how='inner')

# %%
merged_df2
# Out:
#         subject_id   stay_id       los  seq_num   chartdate icd_code_x  \
# 0         14435996  31983544  3.025625        1  2143-04-29       8102
# 1         14435996  31983544  3.025625        1  2143-04-29       8102
# 2         14435996  31983544  3.025625        1  2143-04-29       8102
# 3         14435996  31983544  3.025625        2  2143-04-29       8051
# 4         14435996  31983544  3.025625        2  2143-04-29       8051
# ...            ...       ...       ...      ...         ...        ...
# 917440    17577670  39993265  2.579363        5  2154-01-09       4639
# 917441    17577670  39993265  2.579363        5  2154-01-09       4639
# 917442    17577670  39993265  2.579363        6  2154-01-10       3893
# 917443    17577670  39993265  2.579363        6  2154-01-10       3893
# 917444    17577670  39993265  2.579363        6  2154-01-10       3893
#
#         icd_version icd_code_y     long_title gender  anchor_age  anchor_year  \
# ...

# %%
filtered_df3 = merged_df2[merged_df2['anchor_age'] > 65]

# %%
filtered_df3
# Out:
#         subject_id   stay_id        los  seq_num   chartdate icd_code_x  \
# 54        17675016  36961856  16.921725        1  2173-04-03       9672
# 55        17675016  36961856  16.921725        1  2173-04-03       9672
# 56        17675016  36961856  16.921725        1  2173-04-03       9672
# 57        17675016  36961856  16.921725        2  2173-04-05        311
# 58        17675016  36961856  16.921725        2  2173-04-05        311
# ...            ...       ...        ...      ...         ...        ...
# 917440    17577670  39993265   2.579363        5  2154-01-09       4639
# 917441    17577670  39993265   2.579363        5  2154-01-09       4639
# 917442    17577670  39993265   2.579363        6  2154-01-10       3893
# 917443    17577670  39993265   2.579363        6  2154-01-10       3893
# 917444    17577670  39993265   2.579363        6  2154-01-10       3893
#
#         icd_version icd_code_y     long_title gender  anchor_age  anchor_year  \
# ...

# %%
filtered_df3 = filtered_df3.drop(columns=['anchor_year', 'dod', 'anchor_year_group','seq_num'])

# %%
filtered_df3
# Out:
#         subject_id   stay_id        los   chartdate icd_code_x  icd_version  \
# 54        17675016  36961856  16.921725  2173-04-03       9672            9
# 55        17675016  36961856  16.921725  2173-04-03       9672            9
# 56        17675016  36961856  16.921725  2173-04-03       9672            9
# 57        17675016  36961856  16.921725  2173-04-05        311            9
# 58        17675016  36961856  16.921725  2173-04-05        311            9
# ...            ...       ...        ...         ...        ...          ...
# 917440    17577670  39993265   2.579363  2154-01-09       4639            9
# 917441    17577670  39993265   2.579363  2154-01-09       4639            9
# 917442    17577670  39993265   2.579363  2154-01-10       3893            9
# 917443    17577670  39993265   2.579363  2154-01-10       3893            9
# 917444    17577670  39993265   2.579363  2154-01-10       3893            9
#
# ...

# %%
filtered_df4 = filtered_df3[filtered_df3['icd_code_y'].isin(['99592'])]

# %%
filtered_df4.shape
# Out:
# (127466, 10)

# %%
filtered_df3['admission_number'] = filtered_df3.groupby('subject_id').cumcount() + 1

# %%
filtered_df5 = filtered_df3[filtered_df3['admission_number'] == 1]

# %%
filtered_df5.shape
# Out:
# (9201, 11)

# %%
filtered_df5.head()
# Out:
#      subject_id   stay_id        los   chartdate icd_code_x  icd_version  \
# 54     17675016  36961856  16.921725  2173-04-03       9672            9
# 219    16828280  30007565  18.805278  2141-07-09       3778            9
# 228    15408126  30013597   3.695521  2138-05-17       3979            9
# 378    18340438  30029566   2.227118  2115-04-24       9604            9
# 522    12247460  30031157   3.419988  2164-03-25        966            9
#
#     icd_code_y    long_title gender  anchor_age  admission_number
# 54       78552  Septic shock      M          73                 1
# 219      78552  Septic shock      M          84                 1
# 228      78552  Septic shock      M          80                 1
# 378      78552  Septic shock      F          76                 1
# 522      78552  Septic shock      F          69                 1

# %%
/content/drive/My Drive/535 Project Data/Data/mimic-iv-1.0/icu/icustays.csv

# %%
filename = '/content/drive/My Drive/535 Project Data/Data/output_file.csv'

# %%
filtered_df5.to_csv(filename, index=False)
